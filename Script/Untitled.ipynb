# %%
import IPython
import librosa
import pandas as pd
import numpy as np
import librosa.display
import matplotlib.pyplot as plt
import noisereduce as nr
import tqdm
import soundfile as sf
from scipy.io import wavfile
#### 25000

# %%
url='/home/camilo/Downloads/fish.wav'
test='/home/camilo/Documents/covid-tos/dataset/test/test/tos/3-125418-A-24.wav'
audio_limpio='/home/camilo/Documents/covid-tos/dataset/test/cough/1_Negativo_34_f_22-6-20_2.wav'
audio_ruido='/home/camilo/Documents/covid-tos/dataset/test/cough/581_Positivo_31_m_28-5-20_1.wav'
a='/home/camilo/Documents/covid-tos/dataset/test/test/tos/29_Positivo_56_m_22-6-20_1.wav'
b='/home/camilo/Documents/covid-tos/dataset/test/test/tos/1-58792-A-24.wav'

# %%
data, sr= librosa.core.load(b, sr=sr)
IPython.display.Audio(data=data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noisy_part=data
noise_reduced = nr.reduce_noise(audio_clip=data, noise_clip=noisy_part)

# %%
IPython.display.Audio(data=noise_reduced, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n_mels=500
data = librosa.core.load(b, sr=sr)[0] 
whale_song, _ = librosa.effects.trim(data)
S = librosa.feature.melspectrogram(whale_song, sr=sr, n_mels=n_mels)
S_DB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_DB, sr=sr, x_axis='time', y_axis='mel');
plt.colorbar(format='%+2.0f dB');
display(librosa.display.waveplot(whale_song, sr=sr))

# %%
n_mels=500
#data = librosa.core.load(noise_reduced, sr=sr)[0] 
whale_song, _ = librosa.effects.trim(noise_reduced)
S = librosa.feature.melspectrogram(whale_song, sr=sr, n_mels=n_mels)
S_DB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_DB[0:400], sr=sr, x_axis='time', y_axis='mel');
plt.colorbar(format='%+2.0f dB');
