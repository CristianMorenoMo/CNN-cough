# %%
import librosa
import librosa.display
import glob
import numpy as np

# %%
n_mels = 128
hop_length = 10000

# %%
S = librosa.feature.melspectrogram(whale_song, n_fft=16000, hop_length=hop_length, n_mels=n_mels)
S_DB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_DB, hop_length=hop_length, x_axis='time', y_axis='mel');

# %%
train_files = glob.glob('../dataset/dataset_train_CNN_sigmo/*.wav')
y = librosa.load(train_files[2])[0]
whale_song, _ = librosa.effects.trim(y)
librosa.display.waveplot(whale_song);
